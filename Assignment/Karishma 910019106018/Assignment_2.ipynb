# %% [markdown]
# <a href="https://colab.research.google.com/github/IBM-EPBL/IBM-Project-6213-1658824695/blob/main/Assignment/Karishma%20910019106018/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment-2 Data Visualization and Data Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# the dataset is downloaded

# %% [markdown]
# # 2. Load the dataset

# %%
load = pd.read_csv('/content/Churn_Modelling.csv')

# %%
load
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
load.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
load.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# # 3. Perform Below Visualization

# %% [markdown]
# A. Univariate Analysis

# %%
#Single variable (CreditScore) anlysis for standard parameters (mean, median, standard deviation)
load['CreditScore'].mean()
# Out:
# 650.5288

# %%
load['CreditScore'].median()
# Out:
# 652.0

# %%
load['CreditScore'].std()
# Out:
# 96.65329873613035

# %%
load['CreditScore'].value_counts()
# Out:
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: CreditScore, Length: 460, dtype: int64

# %% [markdown]
# B. Bi-variate Analysis

# %%
#bi-variable analysis between CreditScore & Is
plt.scatter(load.CreditScore, load.EstimatedSalary)
plt.xlabel('Credit Score')
plt.ylabel('Estimated Salary')
# Out:
# Text(0, 0.5, 'Estimated Salary')

# %%
#bi-variable analysis between CreditScore & NumOfProducts
plt.scatter(load.NumOfProducts, load.CreditScore)
plt.xlabel('NumOfProducts')
plt.ylabel('Credit Score')
# Out:
# Text(0, 0.5, 'Credit Score')

# %% [markdown]
# C. Multi-variate Analysis

# %%
pd.plotting.scatter_matrix(load.loc[:, "RowNumber":"Exited"], diagonal="kde",figsize=(20,15))
plt.show()

# %% [markdown]
# # 4.Perform Descriptive Analysis on the dataset

# %%
load.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
load.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # 5. Handle the Missing Values

# %%
load.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
load.duplicated().sum()
# Out:
# 0

# %%
# there is no null elements (missing values) & no duplicate elements

# %% [markdown]
# # 6.Find the Outliers and replace the Outliers

# %%
import plotly.express as px

# %%
fig=px.box(load, y="CreditScore")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
load[load['CreditScore'] > 718]
load[load['CreditScore'] < 584]
new_load = load[load['CreditScore'] < 718]
new_load.shape
# Out:
# (7499, 14)

# %%
load.shape
# Out:
# (10000, 14)

# %%
  # we could see that in the actual dataset there are 10000 rows/Customer/Elements and they are reduced to 7499 
  # when the outliers are removed (whose credit score are between 584 to 718)

# %% [markdown]
# # 7.Check for categorical columns and perform encoding

# %%
load.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# we could see that Surname, Geography & Age are in object data type
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
load['Surname'] = le.fit_transform(load['Surname'])
load['Geography'] = le.fit_transform(load['Geography'])
load['Gender'] = le.fit_transform(load['Gender'])

# %%
load
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602     1115          619          0       0   42
# 1             2    15647311     1177          608          2       0   41
# 2             3    15619304     2040          502          0       0   42
# 3             4    15701354      289          699          0       0   39
# 4             5    15737888     1822          850          2       0   43
# ...         ...         ...      ...          ...        ...     ...  ...
# 9995       9996    15606229     1999          771          0       1   39
# 9996       9997    15569892     1336          516          0       1   35
# 9997       9998    15584532     1570          709          0       0   36
# 9998       9999    15682355     2345          772          1       1   42
# 9999      10000    15628319     2751          792          0       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# we could see that all three are changed into int64 data

# %% [markdown]
# # 8. Split the data into dependent and independent variable

# %%
x = load.iloc[:,3:13].values
y = load.iloc[:,13:14].values

# %%
# All the rows from CreditScore to Estimated Salary comes under independent variable
x
# Out:
# array([[6.1900000e+02, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0134888e+05],
#        [6.0800000e+02, 2.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.1254258e+05],
#        [5.0200000e+02, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1393157e+05],
#        ...,
#        [7.0900000e+02, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 4.2085580e+04],
#        [7.7200000e+02, 1.0000000e+00, 1.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 9.2888520e+04],
#        [7.9200000e+02, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 3.8190780e+04]])

# %%
# The final column (Exited) comes under dependent variable
y
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]])

# %% [markdown]
# # 9. Scale the independent variable

# %%
def normalize(arr, t_min, t_max):
    norm_arr = []
    diff = t_max - t_min
    diff_arr = max(arr) - min(arr)
    for i in arr:
        temp = (((i - min(arr))*diff)/diff_arr) + t_min
        norm_arr.append(temp)
    return norm_arr
range_to_normalize= (0,1)
normalized_y = normalize(y, range_to_normalize[0], 
  range_to_normalize[1])

# %%
# the independent variable (Exited) will be normalized between 0 to 1
normalized_y
# Out:
# [array([1.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
# ...

# %%
# we could see that the dependent variable is between 0 & 1

# %% [markdown]
# # 10. Split the data into Training and Testing

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.4,random_state=0)

# %%
#test size is 0.4 so 6000 samples are used to train the model
xtrain.shape
# Out:
# (6000, 10)

# %%
#test size is 0.4 so 4000 samples are taken for test at random
xtest.shape
# Out:
# (4000, 10)

# %%
#test size is 0.4 so 6000 samples are used to train the model
ytrain.shape
# Out:
# (6000, 1)

# %%
#test size is 0.4 so 4000 samples are taken for test at random
ytest.shape
# Out:
# (4000, 1)
